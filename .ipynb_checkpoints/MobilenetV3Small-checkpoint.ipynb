# %%
from tensorflow.keras import Model
from tensorflow.keras.applications import MobileNetV3Small
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import itertools
import matplotlib.pyplot as plt
import numpy as np

# %%
#Limit GPU Memory Growth to only what's needed
import tensorflow as tf 
physical_devices = tf.config.list_physical_devices('GPU')

try:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
except:
    print('Failed to limit GPU memory')

# %%
#Gather Pre-proccessed images 

img_size = 512;
train_path = 'dataset-classification/train-segmented'
valid_path = 'dataset-classification/validate-segmented'

train_generator = ImageDataGenerator().flow_from_directory(train_path, target_size=(img_size,img_size))
valid_generator = ImageDataGenerator().flow_from_directory(valid_path, target_size=(img_size,img_size))
# Out:
# Found 2400 images belonging to 3 classes.
# Found 300 images belonging to 3 classes.

# %%
#Build Model 

base_model = MobileNetV3Small(weights='imagenet', include_top = False, input_shape=(img_size,img_size,3))

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)
x = Dense(256, activation='relu')(x)
x = Dense(128, activation='relu')(x)
preds = Dense(3, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs = preds)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.

# %%
#model.summary()

# %%
for layers in model.layers[:-20]:
    layers.trainable = False

# %%
#model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 512, 512, 3)  0           ['input_1[0][0]']
#
#  Conv (Conv2D)                  (None, 256, 256, 16  432         ['rescaling[0][0]']
#                                 )
#
#  Conv/BatchNorm (BatchNormaliza  (None, 256, 256, 16  64         ['Conv[0][0]']
#  tion)                          )
#
#  tf.__operators__.add (TFOpLamb  (None, 256, 256, 16  0          ['Conv/BatchNorm[0][0]']
#  da)                            )
#
#  re_lu (ReLU)                   (None, 256, 256, 16  0           ['tf.__operators__.add[0][0]']
#                                 )
#
#  tf.math.multiply (TFOpLambda)  (None, 256, 256, 16  0           ['re_lu[0][0]']
#                                 )
#
#  multiply (Multiply)            (None, 256, 256, 16  0           ['Conv/BatchNorm[0][0]',
#                                 )                                 'tf.math.multiply[0][0]']
#
#  expanded_conv/depthwise/pad (Z  (None, 257, 257, 16  0          ['multiply[0][0]']
#  eroPadding2D)                  )
#
#  expanded_conv/depthwise (Depth  (None, 128, 128, 16  144        ['expanded_conv/depthwise/pad[0][
#  wiseConv2D)                    )                                0]']
#
#  expanded_conv/depthwise/BatchN  (None, 128, 128, 16  64         ['expanded_conv/depthwise[0][0]']
#  orm (BatchNormalization)       )
#
#  re_lu_1 (ReLU)                 (None, 128, 128, 16  0           ['expanded_conv/depthwise/BatchNo
#                                 )                                rm[0][0]']
#
#  expanded_conv/squeeze_excite/A  (None, 1, 1, 16)    0           ['re_lu_1[0][0]']
#  vgPool (GlobalAveragePooling2D
#  )
#
#  expanded_conv/squeeze_excite/C  (None, 1, 1, 8)     136         ['expanded_conv/squeeze_excite/Av
#  onv (Conv2D)                                                    gPool[0][0]']
#
#  expanded_conv/squeeze_excite/R  (None, 1, 1, 8)     0           ['expanded_conv/squeeze_excite/Co
#  elu (ReLU)                                                      nv[0][0]']
#
#  expanded_conv/squeeze_excite/C  (None, 1, 1, 16)    144         ['expanded_conv/squeeze_excite/Re
#  onv_1 (Conv2D)                                                  lu[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 1, 1, 16)    0           ['expanded_conv/squeeze_excite/Co
#  mbda)                                                           nv_1[0][0]']
#
#  re_lu_2 (ReLU)                 (None, 1, 1, 16)     0           ['tf.__operators__.add_1[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 1, 1, 16)    0           ['re_lu_2[0][0]']
#  )
#
#  expanded_conv/squeeze_excite/M  (None, 128, 128, 16  0          ['re_lu_1[0][0]',
#  ul (Multiply)                  )                                 'tf.math.multiply_1[0][0]']
#
#  expanded_conv/project (Conv2D)  (None, 128, 128, 16  256        ['expanded_conv/squeeze_excite/Mu
#                                 )                                l[0][0]']
#
#  expanded_conv/project/BatchNor  (None, 128, 128, 16  64         ['expanded_conv/project[0][0]']
#  m (BatchNormalization)         )
#
#  expanded_conv_1/expand (Conv2D  (None, 128, 128, 72  1152       ['expanded_conv/project/BatchNorm
#  )                              )                                [0][0]']
#
#  expanded_conv_1/expand/BatchNo  (None, 128, 128, 72  288        ['expanded_conv_1/expand[0][0]']
#  rm (BatchNormalization)        )
#
#  re_lu_3 (ReLU)                 (None, 128, 128, 72  0           ['expanded_conv_1/expand/BatchNor
#                                 )                                m[0][0]']
#
#  expanded_conv_1/depthwise/pad   (None, 129, 129, 72  0          ['re_lu_3[0][0]']
#  (ZeroPadding2D)                )
#
#  expanded_conv_1/depthwise (Dep  (None, 64, 64, 72)  648         ['expanded_conv_1/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#  expanded_conv_1/depthwise/Batc  (None, 64, 64, 72)  288         ['expanded_conv_1/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_4 (ReLU)                 (None, 64, 64, 72)   0           ['expanded_conv_1/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_1/project (Conv2  (None, 64, 64, 24)  1728        ['re_lu_4[0][0]']
#  D)
#
#  expanded_conv_1/project/BatchN  (None, 64, 64, 24)  96          ['expanded_conv_1/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/expand (Conv2D  (None, 64, 64, 88)  2112        ['expanded_conv_1/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_2/expand/BatchNo  (None, 64, 64, 88)  352         ['expanded_conv_2/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_5 (ReLU)                 (None, 64, 64, 88)   0           ['expanded_conv_2/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_2/depthwise (Dep  (None, 64, 64, 88)  792         ['re_lu_5[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_2/depthwise/Batc  (None, 64, 64, 88)  352         ['expanded_conv_2/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_6 (ReLU)                 (None, 64, 64, 88)   0           ['expanded_conv_2/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_2/project (Conv2  (None, 64, 64, 24)  2112        ['re_lu_6[0][0]']
#  D)
#
#  expanded_conv_2/project/BatchN  (None, 64, 64, 24)  96          ['expanded_conv_2/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/Add (Add)      (None, 64, 64, 24)   0           ['expanded_conv_1/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_2/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_3/expand (Conv2D  (None, 64, 64, 96)  2304        ['expanded_conv_2/Add[0][0]']
#  )
#
#  expanded_conv_3/expand/BatchNo  (None, 64, 64, 96)  384         ['expanded_conv_3/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_2 (TFOpLa  (None, 64, 64, 96)  0           ['expanded_conv_3/expand/BatchNor
#  mbda)                                                           m[0][0]']
#
#  re_lu_7 (ReLU)                 (None, 64, 64, 96)   0           ['tf.__operators__.add_2[0][0]']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 64, 64, 96)  0           ['re_lu_7[0][0]']
#  )
#
#  multiply_1 (Multiply)          (None, 64, 64, 96)   0           ['expanded_conv_3/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_2[0][0]']
#
#  expanded_conv_3/depthwise/pad   (None, 67, 67, 96)  0           ['multiply_1[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_3/depthwise (Dep  (None, 32, 32, 96)  2400        ['expanded_conv_3/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_3/depthwise/Batc  (None, 32, 32, 96)  384         ['expanded_conv_3/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 32, 32, 96)  0           ['expanded_conv_3/depthwise/Batch
#  mbda)                                                           Norm[0][0]']
#
#  re_lu_8 (ReLU)                 (None, 32, 32, 96)   0           ['tf.__operators__.add_3[0][0]']
#
#  tf.math.multiply_3 (TFOpLambda  (None, 32, 32, 96)  0           ['re_lu_8[0][0]']
#  )
#
#  multiply_2 (Multiply)          (None, 32, 32, 96)   0           ['expanded_conv_3/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_3[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 96)    0           ['multiply_2[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    2328        ['expanded_conv_3/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    0           ['expanded_conv_3/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 96)    2400        ['expanded_conv_3/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 1, 1, 96)    0           ['expanded_conv_3/squeeze_excite/
#  mbda)                                                           Conv_1[0][0]']
#
#  re_lu_9 (ReLU)                 (None, 1, 1, 96)     0           ['tf.__operators__.add_4[0][0]']
#
#  tf.math.multiply_4 (TFOpLambda  (None, 1, 1, 96)    0           ['re_lu_9[0][0]']
#  )
#
#  expanded_conv_3/squeeze_excite  (None, 32, 32, 96)  0           ['multiply_2[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_4[0][0]']
#
#  expanded_conv_3/project (Conv2  (None, 32, 32, 40)  3840        ['expanded_conv_3/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_3/project/BatchN  (None, 32, 32, 40)  160         ['expanded_conv_3/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/expand (Conv2D  (None, 32, 32, 240)  9600       ['expanded_conv_3/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_4/expand/BatchNo  (None, 32, 32, 240)  960        ['expanded_conv_4/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_5 (TFOpLa  (None, 32, 32, 240)  0          ['expanded_conv_4/expand/BatchNor
#  mbda)                                                           m[0][0]']
#
#  re_lu_10 (ReLU)                (None, 32, 32, 240)  0           ['tf.__operators__.add_5[0][0]']
#
#  tf.math.multiply_5 (TFOpLambda  (None, 32, 32, 240)  0          ['re_lu_10[0][0]']
#  )
#
#  multiply_3 (Multiply)          (None, 32, 32, 240)  0           ['expanded_conv_4/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_5[0][0]']
#
#  expanded_conv_4/depthwise (Dep  (None, 32, 32, 240)  6000       ['multiply_3[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_4/depthwise/Batc  (None, 32, 32, 240)  960        ['expanded_conv_4/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_6 (TFOpLa  (None, 32, 32, 240)  0          ['expanded_conv_4/depthwise/Batch
#  mbda)                                                           Norm[0][0]']
#
#  re_lu_11 (ReLU)                (None, 32, 32, 240)  0           ['tf.__operators__.add_6[0][0]']
#
#  tf.math.multiply_6 (TFOpLambda  (None, 32, 32, 240)  0          ['re_lu_11[0][0]']
#  )
#
#  multiply_4 (Multiply)          (None, 32, 32, 240)  0           ['expanded_conv_4/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_6[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 240)   0           ['multiply_4[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 64)    15424       ['expanded_conv_4/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 64)    0           ['expanded_conv_4/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 240)   15600       ['expanded_conv_4/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 1, 1, 240)   0           ['expanded_conv_4/squeeze_excite/
#  mbda)                                                           Conv_1[0][0]']
#
#  re_lu_12 (ReLU)                (None, 1, 1, 240)    0           ['tf.__operators__.add_7[0][0]']
#
#  tf.math.multiply_7 (TFOpLambda  (None, 1, 1, 240)   0           ['re_lu_12[0][0]']
#  )
#
#  expanded_conv_4/squeeze_excite  (None, 32, 32, 240)  0          ['multiply_4[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_7[0][0]']
#
#  expanded_conv_4/project (Conv2  (None, 32, 32, 40)  9600        ['expanded_conv_4/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_4/project/BatchN  (None, 32, 32, 40)  160         ['expanded_conv_4/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/Add (Add)      (None, 32, 32, 40)   0           ['expanded_conv_3/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_4/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_5/expand (Conv2D  (None, 32, 32, 240)  9600       ['expanded_conv_4/Add[0][0]']
#  )
#
#  expanded_conv_5/expand/BatchNo  (None, 32, 32, 240)  960        ['expanded_conv_5/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_8 (TFOpLa  (None, 32, 32, 240)  0          ['expanded_conv_5/expand/BatchNor
#  mbda)                                                           m[0][0]']
#
#  re_lu_13 (ReLU)                (None, 32, 32, 240)  0           ['tf.__operators__.add_8[0][0]']
#
#  tf.math.multiply_8 (TFOpLambda  (None, 32, 32, 240)  0          ['re_lu_13[0][0]']
#  )
#
#  multiply_5 (Multiply)          (None, 32, 32, 240)  0           ['expanded_conv_5/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_8[0][0]']
#
#  expanded_conv_5/depthwise (Dep  (None, 32, 32, 240)  6000       ['multiply_5[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_5/depthwise/Batc  (None, 32, 32, 240)  960        ['expanded_conv_5/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_9 (TFOpLa  (None, 32, 32, 240)  0          ['expanded_conv_5/depthwise/Batch
#  mbda)                                                           Norm[0][0]']
#
#  re_lu_14 (ReLU)                (None, 32, 32, 240)  0           ['tf.__operators__.add_9[0][0]']
#
#  tf.math.multiply_9 (TFOpLambda  (None, 32, 32, 240)  0          ['re_lu_14[0][0]']
#  )
#
#  multiply_6 (Multiply)          (None, 32, 32, 240)  0           ['expanded_conv_5/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_9[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 240)   0           ['multiply_6[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 64)    15424       ['expanded_conv_5/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 64)    0           ['expanded_conv_5/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 240)   15600       ['expanded_conv_5/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_10 (TFOpL  (None, 1, 1, 240)   0           ['expanded_conv_5/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_15 (ReLU)                (None, 1, 1, 240)    0           ['tf.__operators__.add_10[0][0]']
#
#  tf.math.multiply_10 (TFOpLambd  (None, 1, 1, 240)   0           ['re_lu_15[0][0]']
#  a)
#
#  expanded_conv_5/squeeze_excite  (None, 32, 32, 240)  0          ['multiply_6[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_10[0][0]']
#
#  expanded_conv_5/project (Conv2  (None, 32, 32, 40)  9600        ['expanded_conv_5/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_5/project/BatchN  (None, 32, 32, 40)  160         ['expanded_conv_5/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_5/Add (Add)      (None, 32, 32, 40)   0           ['expanded_conv_4/Add[0][0]',
#                                                                   'expanded_conv_5/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_6/expand (Conv2D  (None, 32, 32, 120)  4800       ['expanded_conv_5/Add[0][0]']
#  )
#
#  expanded_conv_6/expand/BatchNo  (None, 32, 32, 120)  480        ['expanded_conv_6/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_11 (TFOpL  (None, 32, 32, 120)  0          ['expanded_conv_6/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_16 (ReLU)                (None, 32, 32, 120)  0           ['tf.__operators__.add_11[0][0]']
#
#  tf.math.multiply_11 (TFOpLambd  (None, 32, 32, 120)  0          ['re_lu_16[0][0]']
#  a)
#
#  multiply_7 (Multiply)          (None, 32, 32, 120)  0           ['expanded_conv_6/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_11[0][0]']
#
#  expanded_conv_6/depthwise (Dep  (None, 32, 32, 120)  3000       ['multiply_7[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_6/depthwise/Batc  (None, 32, 32, 120)  480        ['expanded_conv_6/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_12 (TFOpL  (None, 32, 32, 120)  0          ['expanded_conv_6/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_17 (ReLU)                (None, 32, 32, 120)  0           ['tf.__operators__.add_12[0][0]']
#
#  tf.math.multiply_12 (TFOpLambd  (None, 32, 32, 120)  0          ['re_lu_17[0][0]']
#  a)
#
#  multiply_8 (Multiply)          (None, 32, 32, 120)  0           ['expanded_conv_6/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_12[0][0]']
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 120)   0           ['multiply_8[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_6/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_6/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_6/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_13 (TFOpL  (None, 1, 1, 120)   0           ['expanded_conv_6/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_18 (ReLU)                (None, 1, 1, 120)    0           ['tf.__operators__.add_13[0][0]']
#
#  tf.math.multiply_13 (TFOpLambd  (None, 1, 1, 120)   0           ['re_lu_18[0][0]']
#  a)
#
#  expanded_conv_6/squeeze_excite  (None, 32, 32, 120)  0          ['multiply_8[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_13[0][0]']
#
#  expanded_conv_6/project (Conv2  (None, 32, 32, 48)  5760        ['expanded_conv_6/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_6/project/BatchN  (None, 32, 32, 48)  192         ['expanded_conv_6/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/expand (Conv2D  (None, 32, 32, 144)  6912       ['expanded_conv_6/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_7/expand/BatchNo  (None, 32, 32, 144)  576        ['expanded_conv_7/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_14 (TFOpL  (None, 32, 32, 144)  0          ['expanded_conv_7/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_19 (ReLU)                (None, 32, 32, 144)  0           ['tf.__operators__.add_14[0][0]']
#
#  tf.math.multiply_14 (TFOpLambd  (None, 32, 32, 144)  0          ['re_lu_19[0][0]']
#  a)
#
#  multiply_9 (Multiply)          (None, 32, 32, 144)  0           ['expanded_conv_7/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_14[0][0]']
#
#  expanded_conv_7/depthwise (Dep  (None, 32, 32, 144)  3600       ['multiply_9[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_7/depthwise/Batc  (None, 32, 32, 144)  576        ['expanded_conv_7/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_15 (TFOpL  (None, 32, 32, 144)  0          ['expanded_conv_7/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_20 (ReLU)                (None, 32, 32, 144)  0           ['tf.__operators__.add_15[0][0]']
#
#  tf.math.multiply_15 (TFOpLambd  (None, 32, 32, 144)  0          ['re_lu_20[0][0]']
#  a)
#
#  multiply_10 (Multiply)         (None, 32, 32, 144)  0           ['expanded_conv_7/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_15[0][0]']
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 144)   0           ['multiply_10[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 40)    5800        ['expanded_conv_7/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 40)    0           ['expanded_conv_7/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 144)   5904        ['expanded_conv_7/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_16 (TFOpL  (None, 1, 1, 144)   0           ['expanded_conv_7/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_21 (ReLU)                (None, 1, 1, 144)    0           ['tf.__operators__.add_16[0][0]']
#
#  tf.math.multiply_16 (TFOpLambd  (None, 1, 1, 144)   0           ['re_lu_21[0][0]']
#  a)
#
#  expanded_conv_7/squeeze_excite  (None, 32, 32, 144)  0          ['multiply_10[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_16[0][0]']
#
#  expanded_conv_7/project (Conv2  (None, 32, 32, 48)  6912        ['expanded_conv_7/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_7/project/BatchN  (None, 32, 32, 48)  192         ['expanded_conv_7/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/Add (Add)      (None, 32, 32, 48)   0           ['expanded_conv_6/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_7/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_8/expand (Conv2D  (None, 32, 32, 288)  13824      ['expanded_conv_7/Add[0][0]']
#  )
#
#  expanded_conv_8/expand/BatchNo  (None, 32, 32, 288)  1152       ['expanded_conv_8/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_17 (TFOpL  (None, 32, 32, 288)  0          ['expanded_conv_8/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_22 (ReLU)                (None, 32, 32, 288)  0           ['tf.__operators__.add_17[0][0]']
#
#  tf.math.multiply_17 (TFOpLambd  (None, 32, 32, 288)  0          ['re_lu_22[0][0]']
#  a)
#
#  multiply_11 (Multiply)         (None, 32, 32, 288)  0           ['expanded_conv_8/expand/BatchNor
#                                                                  m[0][0]',
# ...
#  tf.math.multiply_20 (TFOpLambd  (None, 16, 16, 576)  0          ['re_lu_25[0][0]']
#  a)
#
#  multiply_13 (Multiply)         (None, 16, 16, 576)  0           ['expanded_conv_9/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_20[0][0]']
#
#  expanded_conv_9/depthwise (Dep  (None, 16, 16, 576)  14400      ['multiply_13[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_9/depthwise/Batc  (None, 16, 16, 576)  2304       ['expanded_conv_9/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_21 (TFOpL  (None, 16, 16, 576)  0          ['expanded_conv_9/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_26 (ReLU)                (None, 16, 16, 576)  0           ['tf.__operators__.add_21[0][0]']
#
#  tf.math.multiply_21 (TFOpLambd  (None, 16, 16, 576)  0          ['re_lu_26[0][0]']
#  a)
#
#  multiply_14 (Multiply)         (None, 16, 16, 576)  0           ['expanded_conv_9/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_21[0][0]']
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 576)   0           ['multiply_14[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 144)   83088       ['expanded_conv_9/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 144)   0           ['expanded_conv_9/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 576)   83520       ['expanded_conv_9/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_22 (TFOpL  (None, 1, 1, 576)   0           ['expanded_conv_9/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_27 (ReLU)                (None, 1, 1, 576)    0           ['tf.__operators__.add_22[0][0]']
#
#  tf.math.multiply_22 (TFOpLambd  (None, 1, 1, 576)   0           ['re_lu_27[0][0]']
#  a)
#
#  expanded_conv_9/squeeze_excite  (None, 16, 16, 576)  0          ['multiply_14[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_22[0][0]']
#
#  expanded_conv_9/project (Conv2  (None, 16, 16, 96)  55296       ['expanded_conv_9/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_9/project/BatchN  (None, 16, 16, 96)  384         ['expanded_conv_9/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_9/Add (Add)      (None, 16, 16, 96)   0           ['expanded_conv_8/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_9/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_10/expand (Conv2  (None, 16, 16, 576)  55296      ['expanded_conv_9/Add[0][0]']
#  D)
#
#  expanded_conv_10/expand/BatchN  (None, 16, 16, 576)  2304       ['expanded_conv_10/expand[0][0]']
#  orm (BatchNormalization)
#
#  tf.__operators__.add_23 (TFOpL  (None, 16, 16, 576)  0          ['expanded_conv_10/expand/BatchNo
#  ambda)                                                          rm[0][0]']
#
#  re_lu_28 (ReLU)                (None, 16, 16, 576)  0           ['tf.__operators__.add_23[0][0]']
#
#  tf.math.multiply_23 (TFOpLambd  (None, 16, 16, 576)  0          ['re_lu_28[0][0]']
#  a)
#
#  multiply_15 (Multiply)         (None, 16, 16, 576)  0           ['expanded_conv_10/expand/BatchNo
#                                                                  rm[0][0]',
#                                                                   'tf.math.multiply_23[0][0]']
#
#  expanded_conv_10/depthwise (De  (None, 16, 16, 576)  14400      ['multiply_15[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_10/depthwise/Bat  (None, 16, 16, 576)  2304       ['expanded_conv_10/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf.__operators__.add_24 (TFOpL  (None, 16, 16, 576)  0          ['expanded_conv_10/depthwise/Batc
#  ambda)                                                          hNorm[0][0]']
#
#  re_lu_29 (ReLU)                (None, 16, 16, 576)  0           ['tf.__operators__.add_24[0][0]']
#
#  tf.math.multiply_24 (TFOpLambd  (None, 16, 16, 576)  0          ['re_lu_29[0][0]']
#  a)
#
#  multiply_16 (Multiply)         (None, 16, 16, 576)  0           ['expanded_conv_10/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf.math.multiply_24[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 576)   0           ['multiply_16[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 144)   83088       ['expanded_conv_10/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 144)   0           ['expanded_conv_10/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 576)   83520       ['expanded_conv_10/squeeze_excite
#  e/Conv_1 (Conv2D)                                               /Relu[0][0]']
#
#  tf.__operators__.add_25 (TFOpL  (None, 1, 1, 576)   0           ['expanded_conv_10/squeeze_excite
#  ambda)                                                          /Conv_1[0][0]']
#
#  re_lu_30 (ReLU)                (None, 1, 1, 576)    0           ['tf.__operators__.add_25[0][0]']
#
#  tf.math.multiply_25 (TFOpLambd  (None, 1, 1, 576)   0           ['re_lu_30[0][0]']
#  a)
#
#  expanded_conv_10/squeeze_excit  (None, 16, 16, 576)  0          ['multiply_16[0][0]',
#  e/Mul (Multiply)                                                 'tf.math.multiply_25[0][0]']
#
#  expanded_conv_10/project (Conv  (None, 16, 16, 96)  55296       ['expanded_conv_10/squeeze_excite
#  2D)                                                             /Mul[0][0]']
#
#  expanded_conv_10/project/Batch  (None, 16, 16, 96)  384         ['expanded_conv_10/project[0][0]'
#  Norm (BatchNormalization)                                       ]
#
#  expanded_conv_10/Add (Add)     (None, 16, 16, 96)   0           ['expanded_conv_9/Add[0][0]',
#                                                                   'expanded_conv_10/project/BatchN
#                                                                  orm[0][0]']
#
#  Conv_1 (Conv2D)                (None, 16, 16, 576)  55296       ['expanded_conv_10/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNormali  (None, 16, 16, 576)  2304       ['Conv_1[0][0]']
#  zation)
#
#  tf.__operators__.add_26 (TFOpL  (None, 16, 16, 576)  0          ['Conv_1/BatchNorm[0][0]']
#  ambda)
#
#  re_lu_31 (ReLU)                (None, 16, 16, 576)  0           ['tf.__operators__.add_26[0][0]']
#
#  tf.math.multiply_26 (TFOpLambd  (None, 16, 16, 576)  0          ['re_lu_31[0][0]']
#  a)
#
#  multiply_17 (Multiply)         (None, 16, 16, 576)  0           ['Conv_1/BatchNorm[0][0]',
#                                                                   'tf.math.multiply_26[0][0]']
#
#  global_average_pooling2d (Glob  (None, 576)         0           ['multiply_17[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 512)          295424      ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_1 (Dense)                (None, 256)          131328      ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 128)          32896       ['dense_1[0][0]']
#
#  dense_3 (Dense)                (None, 3)            387         ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 1,399,155
# Trainable params: 655,491
# Non-trainable params: 743,664
# __________________________________________________________________________________________________

# %%
epochs = 40

optimizer = Adam(learning_rate = 0.0001)

model.compile(loss='categorical_crossentropy', optimizer = optimizer, metrics=['accuracy'])

history = model.fit(train_generator, validation_data=valid_generator, epochs = epochs)
# Out:
# Epoch 1/40
# 75/75 [==============================] - 62s 494ms/step - loss: 0.6483 - accuracy: 0.7925 - val_loss: 0.6659 - val_accuracy: 0.7267
# Epoch 2/40
# 75/75 [==============================] - 36s 483ms/step - loss: 0.2596 - accuracy: 0.9100 - val_loss: 0.4633 - val_accuracy: 0.8133
# Epoch 3/40
# 75/75 [==============================] - 37s 485ms/step - loss: 0.1539 - accuracy: 0.9471 - val_loss: 0.8587 - val_accuracy: 0.6867
# Epoch 4/40
# 75/75 [==============================] - 34s 453ms/step - loss: 0.0927 - accuracy: 0.9737 - val_loss: 0.7764 - val_accuracy: 0.7167
# Epoch 5/40
# 75/75 [==============================] - 34s 446ms/step - loss: 0.0644 - accuracy: 0.9804 - val_loss: 0.9131 - val_accuracy: 0.7033
# Epoch 6/40
# 75/75 [==============================] - 34s 452ms/step - loss: 0.0518 - accuracy: 0.9837 - val_loss: 0.6186 - val_accuracy: 0.7667
# Epoch 7/40
# 75/75 [==============================] - 34s 457ms/step - loss: 0.0319 - accuracy: 0.9925 - val_loss: 0.6141 - val_accuracy: 0.7733
# Epoch 8/40
# 75/75 [==============================] - 33s 439ms/step - loss: 0.0245 - accuracy: 0.9950 - val_loss: 0.5311 - val_accuracy: 0.8067
# Epoch 9/40
# 75/75 [==============================] - 33s 443ms/step - loss: 0.0249 - accuracy: 0.9942 - val_loss: 0.3703 - val_accuracy: 0.8633
# Epoch 10/40
# 75/75 [==============================] - 33s 445ms/step - loss: 0.0121 - accuracy: 0.9975 - val_loss: 0.9034 - val_accuracy: 0.7400
# Epoch 11/40
# 75/75 [==============================] - 32s 427ms/step - loss: 0.0134 - accuracy: 0.9975 - val_loss: 0.3773 - val_accuracy: 0.8600
# Epoch 12/40
# 75/75 [==============================] - 32s 429ms/step - loss: 0.0075 - accuracy: 0.9983 - val_loss: 0.4425 - val_accuracy: 0.8433
# Epoch 13/40
# 75/75 [==============================] - 32s 432ms/step - loss: 0.0077 - accuracy: 0.9987 - val_loss: 0.6057 - val_accuracy: 0.8000
# Epoch 14/40
# 75/75 [==============================] - 32s 424ms/step - loss: 0.0054 - accuracy: 0.9987 - val_loss: 0.3150 - val_accuracy: 0.8900
# Epoch 15/40
# 75/75 [==============================] - 32s 420ms/step - loss: 0.0060 - accuracy: 0.9987 - val_loss: 0.3086 - val_accuracy: 0.9000
# Epoch 16/40
# 75/75 [==============================] - 32s 423ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2575 - val_accuracy: 0.9000
# Epoch 17/40
# 75/75 [==============================] - 33s 434ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1138 - val_accuracy: 0.9567
# Epoch 18/40
# 75/75 [==============================] - 32s 422ms/step - loss: 0.0039 - accuracy: 0.9992 - val_loss: 0.1670 - val_accuracy: 0.9400
# Epoch 19/40
# 75/75 [==============================] - 32s 425ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1543 - val_accuracy: 0.9467
# Epoch 20/40
# 75/75 [==============================] - 32s 420ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9500
# Epoch 21/40
# 75/75 [==============================] - 32s 421ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2064 - val_accuracy: 0.9267
# Epoch 22/40
# 75/75 [==============================] - 32s 432ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1429 - val_accuracy: 0.9500
# Epoch 23/40
# 75/75 [==============================] - 32s 422ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1657 - val_accuracy: 0.9333
# Epoch 24/40
# 75/75 [==============================] - 32s 420ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1151 - val_accuracy: 0.9500
# Epoch 25/40
# 75/75 [==============================] - 32s 427ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9400
# Epoch 26/40
# 75/75 [==============================] - 32s 419ms/step - loss: 7.1612e-04 - accuracy: 1.0000 - val_loss: 0.1109 - val_accuracy: 0.9633
# Epoch 27/40
# 75/75 [==============================] - 31s 417ms/step - loss: 5.6121e-04 - accuracy: 1.0000 - val_loss: 0.0941 - val_accuracy: 0.9667
# Epoch 28/40
# 75/75 [==============================] - 32s 422ms/step - loss: 4.3767e-04 - accuracy: 1.0000 - val_loss: 0.1099 - val_accuracy: 0.9633
# Epoch 29/40
# 75/75 [==============================] - 32s 421ms/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 0.1099 - val_accuracy: 0.9600
# Epoch 30/40
# 75/75 [==============================] - 32s 422ms/step - loss: 0.0111 - accuracy: 0.9950 - val_loss: 0.0727 - val_accuracy: 0.9867
# Epoch 31/40
# 75/75 [==============================] - 32s 422ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 0.1206 - val_accuracy: 0.9667
# Epoch 32/40
# 75/75 [==============================] - 33s 439ms/step - loss: 5.4950e-04 - accuracy: 1.0000 - val_loss: 0.1246 - val_accuracy: 0.9633
# Epoch 33/40
# 75/75 [==============================] - 38s 498ms/step - loss: 5.0581e-04 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9700
# Epoch 34/40
# 75/75 [==============================] - 35s 468ms/step - loss: 3.5844e-04 - accuracy: 1.0000 - val_loss: 0.0964 - val_accuracy: 0.9733
# Epoch 35/40
# 75/75 [==============================] - 31s 417ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1092 - val_accuracy: 0.9667
# Epoch 36/40
# 75/75 [==============================] - 32s 429ms/step - loss: 9.2694e-04 - accuracy: 1.0000 - val_loss: 0.1334 - val_accuracy: 0.9633
# Epoch 37/40
# 75/75 [==============================] - 31s 406ms/step - loss: 2.1530e-04 - accuracy: 1.0000 - val_loss: 0.0855 - val_accuracy: 0.9733
# Epoch 38/40
# 75/75 [==============================] - 31s 406ms/step - loss: 1.9250e-04 - accuracy: 1.0000 - val_loss: 0.0945 - val_accuracy: 0.9700
# Epoch 39/40
# 75/75 [==============================] - 30s 404ms/step - loss: 2.3230e-04 - accuracy: 1.0000 - val_loss: 0.0944 - val_accuracy: 0.9733
# Epoch 40/40
# 75/75 [==============================] - 31s 410ms/step - loss: 1.6212e-04 - accuracy: 1.0000 - val_loss: 0.0847 - val_accuracy: 0.9767

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('MobilenetV3Large Train vs Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('MobilenetV3Large Train vs Validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'], loc='upper left')
plt.show()

# %%
test_path = 'dataset-classification/test-segmented'
test_generator = ImageDataGenerator().flow_from_directory(test_path, target_size=(img_size,img_size))
predictions = model.predict(x = test_generator, verbose = 0)
# Out:
# Found 300 images belonging to 3 classes.

# %%
test_labels = test_generator.classes
cm = confusion_matrix(y_true=test_labels, y_pred=predictions.argmax(axis=1))
test_generator.class_indices
# Out:
# {'-K': 0, '-N': 1, 'FN': 2}

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['-K', '-N', 'Healthy'])
disp.plot()
plt.show()

# %%
from sklearn.metrics import classification_report 

print(classification_report(test_labels,predictions.argmax(axis=1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.41      0.40      0.41       100
#            1       0.40      0.40      0.40       100
#            2       0.34      0.35      0.34       100
#
#     accuracy                           0.38       300
#    macro avg       0.38      0.38      0.38       300
# weighted avg       0.38      0.38      0.38       300

# %%
#model.save("MNetSmall.h5")
