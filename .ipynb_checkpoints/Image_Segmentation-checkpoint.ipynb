# %% [markdown]
# ### Imports

# %%
from keras_segmentation.models.segnet import vgg_segnet
from matplotlib import pyplot as plt
import tensorflow as tf
from imgaug import augmenters as iaa
import os
from PIL import Image
from glob import glob
import skimage.transform as st
import matplotlib.image as mpimg

# %% [markdown]
# ### Model Initialization

# %%
model = vgg_segnet(n_classes=2 ,  input_height=256, input_width=256)

# %% [markdown]
# ### Augmentation

# %%
def custom_augmentation():
    return  iaa.Sequential(
        [
            # apply the following augmenters to most images
            iaa.Fliplr(0.5),  # horizontally flip 50% of all images
            iaa.Flipud(0.5), # horizontally flip 50% of all images
        ])

# %% [markdown]
# ### Model Training

# %%
model.train(
    train_images = "dataset-segmentation/resized/",
    train_annotations = "dataset-segmentation/annotations/",
    # train_images =  "dataset1/images_prepped_train/",
    # train_annotations = "dataset1/annotations_prepped_train/",
    checkpoints_path = "tmp/vgg_segnet_1", 
    epochs=10, 
    do_augment=True, # enable augmentation 
    custom_augmentation=custom_augmentation # sets the augmention function to use
)
# Out:
# Verifying training dataset
# 100%|██████████| 186/186 [00:00<00:00, 470.01it/s]
# Dataset verified!
# Epoch 1/10
# 512/512 [==============================] - ETA: 0s - loss: 0.0801 - accuracy: 0.9724
# Epoch 1: saving model to tmp\vgg_segnet_1.00001
# 512/512 [==============================] - 56s 106ms/step - loss: 0.0801 - accuracy: 0.9724
# Epoch 2/10
# 512/512 [==============================] - ETA: 0s - loss: 0.0655 - accuracy: 0.9773
# Epoch 2: saving model to tmp\vgg_segnet_1.00002
# 512/512 [==============================] - 61s 120ms/step - loss: 0.0655 - accuracy: 0.9773
# Epoch 3/10
# 512/512 [==============================] - ETA: 0s - loss: 0.0585 - accuracy: 0.9792
# Epoch 3: saving model to tmp\vgg_segnet_1.00003
# 512/512 [==============================] - 63s 123ms/step - loss: 0.0585 - accuracy: 0.9792
# Epoch 4/10
# 512/512 [==============================] - ETA: 0s - loss: 0.0534 - accuracy: 0.9809
# Epoch 4: saving model to tmp\vgg_segnet_1.00004
# 512/512 [==============================] - 73s 142ms/step - loss: 0.0534 - accuracy: 0.9809
# Epoch 5/10
# 512/512 [==============================] - ETA: 0s - loss: 0.0446 - accuracy: 0.9835
# Epoch 5: saving model to tmp\vgg_segnet_1.00005
# 512/512 [==============================] - 68s 132ms/step - loss: 0.0446 - accuracy: 0.9835
# Epoch 6/10
# 512/512 [==============================] - ETA: 0s - loss: 0.0569 - accuracy: 0.9799
# Epoch 6: saving model to tmp\vgg_segnet_1.00006
# 512/512 [==============================] - 62s 122ms/step - loss: 0.0569 - accuracy: 0.9799
# Epoch 7/10
# 512/512 [==============================] - ETA: 0s - loss: 0.0425 - accuracy: 0.9844
# Epoch 7: saving model to tmp\vgg_segnet_1.00007
# 512/512 [==============================] - 70s 136ms/step - loss: 0.0425 - accuracy: 0.9844
# Epoch 8/10
# 512/512 [==============================] - ETA: 0s - loss: 0.0344 - accuracy: 0.9870
# Epoch 8: saving model to tmp\vgg_segnet_1.00008
# 512/512 [==============================] - 63s 122ms/step - loss: 0.0344 - accuracy: 0.9870
# Epoch 9/10
# 512/512 [==============================] - ETA: 0s - loss: 0.0303 - accuracy: 0.9884
# Epoch 9: saving model to tmp\vgg_segnet_1.00009
# 512/512 [==============================] - 68s 133ms/step - loss: 0.0303 - accuracy: 0.9884
# Epoch 10/10
# 512/512 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 0.9890
# Epoch 10: saving model to tmp\vgg_segnet_1.00010
# 512/512 [==============================] - 62s 121ms/step - loss: 0.0283 - accuracy: 0.9890

# %% [markdown]
# ### Model Predictions

# %%
fn = model.predict_segmentation(
    inp="tmp/images/fn12.png",
    out_fname = "tmp/fn12_out.png", overlay_img = True, show_legends = True,
    class_names = ["background", "lettuce"]
)

n = model.predict_segmentation(
    inp="tmp/images/n_59.png",
    out_fname = "tmp/n_59.png", overlay_img = True, show_legends = True,
    class_names = ["background", "lettuce"]
)

p = model.predict_segmentation(
    inp="tmp/images/p68.png",
    out_fname = "tmp/p68.png", overlay_img = True, show_legends = True,
    class_names = ["background", "lettuce"]
)

k = model.predict_segmentation(
    inp="tmp/images/k_54.png",
    out_fname = "tmp/k_54.png", overlay_img = True, show_legends = True,
    class_names = ["background", "lettuce"]
)
# Out:
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step

# %% [markdown]
# ### Visualizations

# %% [markdown]
# **Resizing predicted masks**

# %%
preds = [fn, k, n, p]
fn = st.resize(fn, (1024, 1024))
n = st.resize(n, (1024, 1024))
p = st.resize(p, (1024,1024))
k = st.resize(k, (1024,1024))

# %% [markdown]
# **Loading files**

# %%
images = glob("tmp/images/*.png")
masks = glob("tmp/masks/*.png")
out = glob("tmp/out/*.png")

images = [mpimg.imread(i) for i in images]
masks = [mpimg.imread(i) for i in masks]
out = [mpimg.imread(i) for i in out]

# %% [markdown]
# **Setting up the array**

# %%
arr = []
for i in range(4):
    arr.insert((i*4), images[i])
    arr.insert((i*4)+1, masks[i])
    arr.insert((i*4)+2, preds[i])
    arr.insert((i*4)+3, out[i])

# %% [markdown]
# **Plotting the results**

# %%
fig, axs = plt.subplots(nrows=4, ncols=4, sharex=True, sharey=True, figsize=(20, 20))
axs = axs.flatten()

y_labels=["FN", "-K", "-N", "-P"]
x_labels = ["Input", "Ground Truth", "Predicted", "Overlay"]

for i in range(len(arr)):
    axs[i].imshow(arr[i], interpolation='none')
    axs[i].set_xticks([])
    axs[i].set_yticks([])

    if i%4 == 0:
        axs[i].set_ylabel(y_labels[i//4])

    if i < 4:
        axs[i].set_xlabel(x_labels[i])
        axs[i].xaxis.set_label_position('top')

# %% [markdown]
# ### Model Evaluation

# %%
print(model.evaluate_segmentation( inp_images_dir="tmp/resized/"  , annotations_dir="tmp/annotations/" ) )
# Out:
# 0it [00:00, ?it/s]
# 1/1 [==============================] - 0s 450ms/step
# 1it [00:07,  7.37s/it]
# 1/1 [==============================] - 0s 50ms/step
# 2it [00:07,  3.24s/it]
# 1/1 [==============================] - 0s 38ms/step
# 3it [00:08,  1.89s/it]
# 1/1 [==============================] - 0s 25ms/step
# 4it [00:08,  2.03s/it]
# {'frequency_weighted_IU': 0.9774917892915933, 'mean_IU': 0.9774760583521105, 'class_wise_IU': array([0.9780388 , 0.97691332])}

# %% [markdown]
# ### Save Model

# %%
model.save("vggseg.h5")
model.save("vggseg")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: vggseg\assets
# INFO:tensorflow:Assets written to: vggseg\assets
